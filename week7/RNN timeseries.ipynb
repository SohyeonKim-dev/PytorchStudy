# %%
import torch
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.manual_seed(0)

# %%
seq_length = 7
data_dim = 5
hedden_dim = 5
output_dim = 1
learning_rate = 0.01
iterations = 500

# %%
xy = np.loadtxt("", delimiter = ",")
xt = xy[::-1]
